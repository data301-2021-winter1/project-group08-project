# %%
from project_functions_utkarsh import load_and_process_file1

# %%
from project_functions_utkarsh import load_and_process_file2

# %%
from project_functions_utkarsh import merge_and_process_dataframes

# %%
eth= load_and_process_file1("/Users/utkarshagarwal/DATA301/project/project-group08-project/data/processed/ethereum cleaned.csv")
eth
# Out:
#            Date         Open        Close         High          Low  \
# 0    2015-08-07     2.831620     2.772120     3.536610     2.521120
# 1    2015-08-08     2.793760     0.753325     2.798810     0.714725
# 2    2015-08-09     0.706136     0.701897     0.879810     0.629191
# 3    2015-08-10     0.713989     0.708448     0.729854     0.636546
# 4    2015-08-11     0.708087     1.067860     1.131410     0.663235
# ...         ...          ...          ...          ...          ...
# 2172 2021-07-22  1994.822876  2025.202759  2044.116455  1954.297852
# 2173 2021-07-23  2025.105713  2124.776611  2129.441162  2000.436279
# 2174 2021-07-24  2123.961182  2189.218750  2197.649414  2107.323486
# 2175 2021-07-25  2187.145508  2191.373779  2194.438232  2108.829834
# 2176 2021-07-26  2191.309814  2233.366699  2428.817139  2177.329590
#
#             Volume
# 0     1.643290e+05
# 1     6.741880e+05
# 2     5.321700e+05
# 3     4.052830e+05
# 4     1.463100e+06
# ...            ...
# ...

# %%
bit= load_and_process_file2("/Users/utkarshagarwal/DATA301/project/project-group08-project/data/processed/Bitcoin Historical Data cleaned.csv")
bit
# Out:
# /Users/utkarshagarwal/DATA301/project/project-group08-project/notebooks/project_functions_utkarsh.py:42: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bit['Volume'].str.replace('.','')
#            Date     Open    Close     High      Low      Volume
# 0    2015-08-07    278.0    277.9    279.6    274.3   4281000.0
# 1    2015-08-08    277.9    258.6    278.9    257.4   8254000.0
# 2    2015-08-09    258.6    263.9    266.8    258.6   5748000.0
# 3    2015-08-10    263.9    263.3    266.6    260.5   4857000.0
# 4    2015-08-11    263.3    269.0    269.9    261.4   5136000.0
# ...         ...      ...      ...      ...      ...         ...
# 2176 2021-07-22  32131.7  32298.9  32585.4  31729.4   6487000.0
# 2177 2021-07-23  32297.9  33603.3  33605.6  32041.1   6615000.0
# ...

# %%
merge1= merge_and_process_dataframes(bit,eth)
merge1
# Out:
#            Date  Open_bit  Close_bit  High_bit  Low_bit  Volume_bit  \
# 0    2015-08-07     278.0      277.9     279.6    274.3   4281000.0
# 1    2015-08-08     277.9      258.6     278.9    257.4   8254000.0
# 2    2015-08-09     258.6      263.9     266.8    258.6   5748000.0
# 3    2015-08-10     263.9      263.3     266.6    260.5   4857000.0
# 4    2015-08-11     263.3      269.0     269.9    261.4   5136000.0
# ...         ...       ...        ...       ...      ...         ...
# 2172 2021-07-22   32131.7    32298.9   32585.4  31729.4   6487000.0
# 2173 2021-07-23   32297.9    33603.3   33605.6  32041.1   6615000.0
# 2174 2021-07-24   33600.5    33824.8   33955.0  33412.9   6714000.0
# 2175 2021-07-25   34392.5    35391.1   35391.1  33881.3   6510000.0
# 2176 2021-07-26   35392.3    38233.2   39639.9  35236.7  16168000.0
#
#          Open_eth    Close_eth     High_eth      Low_eth    Volume_eth
# 0        2.831620     2.772120     3.536610     2.521120  1.643290e+05
# ...

# %%
y=merge1.plot( 'Date' , 'Close_bit' )

# %%
y=merge1.plot( 'Date' , 'Close_eth' )

# %%
y=merge1.plot( kind= 'scatter', x= 'Date' , y= 'Close_bit' )
